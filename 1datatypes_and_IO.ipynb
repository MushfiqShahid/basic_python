# %%
# datatypes

# %%
a = 123
b = 1.2345
c = "Bismillahir Rahmanir Rahim"

# %%
# showing them as an outupt
print(a)
print(b)
print(c)
# Out:
# 123
# 1.2345
# Bismillahir Rahmanir Rahim

# %%
# showing what types of data this is 
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# showing inside a string Like:- My name is (something)
d = 24
e = "Mushfiq"
print("Before beginning any task we have to say,", c,".")
print("My name is:", e)
print("My age is:", d)
# Out:
# Before beginning any task we have to say, Bismillahir Rahmanir Rahim .
# My name is: Mushfiq
# My age is: 24

# %%
# basic operators

# %%
1 + 2
# Out:
# 3

# %%
5 - 3
# Out:
# 2

# %%
2 * 3
# Out:
# 6

# %%
10 / 22
# Out:
# 0.45454545454545453

# %%
10 % 6
# Out:
# 4

# %%
# for power 
2 ** 3
# Out:
# 8
